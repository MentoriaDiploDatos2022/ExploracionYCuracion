# %%
#Primer Parcial - AAED1


print('Inicio Ejercicio 1\n')


cantDeProductos= 10


precios=[]
preciosMayores=[]
productos=[]


prodMasCaro='ninguno'


sumaDePrecios=0




for a in range(cantDeProductos):
    valor=str(input('ingrese el producto #' + str(a+1) + '... '))
    productos.append(valor)
    valor2=int(input('ingrese su precio... $'))
    precios.append(valor2)


    sumaDePrecios+=valor2


#print('lista completa de productos\n' + str(productos) + '\nLista de precios\n' + str(precios))


print('\nPromedio del valor de los productos: $' + str(sumaDePrecios/cantDeProductos))


precioMasCaro = precios[0]
for b in range(cantDeProductos):
    if precios[b] > precioMasCaro:
        precioMasCaro=precios[b]
        prodMasCaro=productos[b]


print('\nEl producto mas caro es: ' + prodMasCaro)


prodMayores=[]


for c in range(cantDeProductos):
    if precios[c] > 1000:
        prodMayores.append(productos[c])


print('/nLos productos que superan los $1000 son: \n' + str(prodMayores))


#---------------------------------------------------------------------------------------''


print('\n\nInicio Ejercicio 2')


valorSumaCaracteres=0
nombre=[]


for a in range(10):
    intento=int(input('\nIngrese una contrasena (intento ' + str(a+1) + '/10)  '))


    for b in range(len(str(intento))):
        valorSumaCaracteres+=intento%10
        intento = intento //10


    if (valorSumaCaracteres%2)==0 and valorSumaCaracteres>20:
        print('\nContrasena Correcta')
        quit()
    else:
        print('\nContrasena Incorrecta, prueba de nuevo')


#---------------------------------------------------------------------------------------''

# %%
print('\n\ninicio Ejercicio 3\n')


for a in range(5, 0, -1):
    for b in range(5, 0, -1):
        if b >= a:
            print(a, end=' ')
        else:
            print(b, end=' ')
    print()
        
#---------------------------------------------------------------------------------------''


print('\n\ninicio Ejercicio 4')


for a in range(5):
    if (a%2)==0:
        print('*'*(a+1))
    else:
        print('#'*(a+1))
# Out:
# inicio Ejercicio 3
#
# 5 4 3 2 1
# 4 4 3 2 1
# 3 3 3 2 1
# 2 2 2 2 1
# 1 1 1 1 1
#
#
# inicio Ejercicio 4
# *
# ##
# ***
# ####
# *****
